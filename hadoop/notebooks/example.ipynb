# %%
# !$HADOOP_PREFIX/bin/hdfs dfs -put $HADOOP_PREFIX/etc/hadoop/ input

# %%
# !$HADOOP_PREFIX/bin/hadoop \
    jar $HADOOP_PREFIX/share/hadoop/mapreduce/hadoop-mapreduce-examples-2.7.2.jar \
    grep input output 'dfs[a-z.]+'
# Out:
# 16/04/06 09:23:15 INFO client.RMProxy: Connecting to ResourceManager at /0.0.0.0:8032
# 16/04/06 09:23:15 INFO input.FileInputFormat: Total input paths to process : 32
# 16/04/06 09:23:15 INFO mapreduce.JobSubmitter: number of splits:32
# 16/04/06 09:23:15 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_1459932351054_0011
# 16/04/06 09:23:16 INFO impl.YarnClientImpl: Submitted application application_1459932351054_0011
# 16/04/06 09:23:16 INFO mapreduce.Job: The url to track the job: http://119b35b22a37:8088/proxy/application_1459932351054_0011/
# 16/04/06 09:23:16 INFO mapreduce.Job: Running job: job_1459932351054_0011
# 16/04/06 09:23:21 INFO mapreduce.Job: Job job_1459932351054_0011 running in uber mode : false
# 16/04/06 09:23:21 INFO mapreduce.Job:  map 0% reduce 0%
# 16/04/06 09:23:33 INFO mapreduce.Job:  map 19% reduce 0%
# 16/04/06 09:23:43 INFO mapreduce.Job:  map 22% reduce 0%
# 16/04/06 09:23:44 INFO mapreduce.Job:  map 34% reduce 0%
# ...

# %%
# !$HADOOP_PREFIX/bin/hdfs dfs -cat output/*
# Out:
# 6	dfs.audit.logger
# 4	dfs.class
# 3	dfs.server.namenode.
# 2	dfs.audit.log.maxbackupindex
# 2	dfs.period
# 2	dfs.audit.log.maxfilesize
# 1	dfsmetrics.log
# 1	dfsadmin
# 1	dfs.servers
# 1	dfs.replication
# 1	dfs.namenode.rpc
# 1	dfs.file
# 1	dfs.namenode.servicerpc
